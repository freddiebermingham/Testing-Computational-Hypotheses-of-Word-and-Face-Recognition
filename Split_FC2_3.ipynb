# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
transform = transforms.ToTensor()

# %%
train_data = datasets.ImageFolder(('/content/gdrive/MyDrive/WF/train'), transform=transform)
test_data = datasets.ImageFolder(('/content/gdrive/MyDrive/WF/test'), transform=transform)

torch.manual_seed(42)
train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=True)

class_names = train_data.classes
labels = train_data.targets

print(class_names)
print(f'Training images available: {len(train_data)}')
print(f'Testing images available:  {len(test_data)}')
# Out:
# ['Aidan_Turner', 'Ashley_Rickards', 'Christina_Hendricks', 'Christine_Lahti', 'Cillian_Murphy', 'Dawn_French', 'Jacqueline_MacInnes_Wood', 'Kari_Matchett', 'Martha_Plimpton', 'Rowan_Atkinson', 'cash ', 'cats', 'fact', 'foot', 'heat', 'holt', 'lots', 'safe', 'soft', 'tell']
# Training images available: 9004
# Testing images available:  1600

# %%
train_data.classes
# Out:
# ['Aidan_Turner',
#  'Ashley_Rickards',
#  'Christina_Hendricks',
#  'Christine_Lahti',
#  'Cillian_Murphy',
#  'Dawn_French',
#  'Jacqueline_MacInnes_Wood',
#  'Kari_Matchett',
#  'Martha_Plimpton',
#  'Rowan_Atkinson',
#  'cash ',
#  'cats',
#  'fact',
#  'foot',
#  'heat',
#  'holt',
#  'lots',
#  'safe',
#  'soft',
#  'tell']

# %%
torch.manual_seed(300)

train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %%
np.set_printoptions(formatter=dict(int=lambda x: f'{x:5}'))

for images,labels in train_loader: 
    break

print('Label:', labels.numpy())
print('Class: ', *np.array([class_names[i] for i in labels]))


im = make_grid(images, nrow=5) 
plt.figure(figsize=(10,4))
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# Label: [    3    18    14     6    17    17     1    15     8    16]
# Class:  Christine_Lahti soft heat Jacqueline_MacInnes_Wood safe safe Ashley_Rickards holt Martha_Plimpton lots

# %%
out1 = 240

# %%
class ConvolutionalNetwork(nn.Sequential):
    def __init__(self):
        super(ConvolutionalNetwork, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 24, 3, 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(24, 12, 3, 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(12, 24, 3, 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(24, 32, 3, 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(32, 32, 3, 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2))
         
        self.fc1 = nn.Sequential(
            nn.Flatten(),
            nn.Linear(5*5*32, out1),
            nn.ReLU())

        self.fc_c = nn.Sequential(
            nn.Linear(out1,20))
        
        self.fc_m = nn.Sequential(
            nn.Linear(out1,20))

    def forward(self, X):
        X = self.layer1(X)
        
        X = X.view(-1, 5*5*32)        
        
        Xm = self.fc1(X)        
        Xc = self.fc1(X)
        
        Xm = self.fc_m(Xm)
        Xc = self.fc_c(Xc)
        
        return F.log_softmax(Xm, dim=1)
        return F.log_softmax(Xc, dim=1)

# %%
torch.manual_seed(300)
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (layer1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=800, out_features=240, bias=True)
#     (2): ReLU()
#   )
#   (fc_c): Sequential(
#     (0): Linear(in_features=240, out_features=20, bias=True)
#   )
#   (fc_m): Sequential(
#     (0): Linear(in_features=240, out_features=20, bias=True)
#   )
# )

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')

# %%
count_parameters(model)
# Out:
#    648
#     24
#   2592
#     12
#   2592
#     24
#   6912
#     32
#   9216
#     32
# 192000
#    240
#   4800
#     20
#   4800
#     20
# ______
# 223964

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
import time
start_time = time.time()

epochs = 10
train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        b+=1
        
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # results
        if b%100 == 0:
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/9000]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%  Duration: {time.time() - start_time:.0f} seconds')
        
    train_losses.append(loss)
    train_correct.append(trn_corr)
        
    # testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):

            
            y_val = model(X_test)

            # Tally number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()
            
    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)
        
print(f'\nDuration: {time.time() - start_time:.0f} seconds')
# Out:
# epoch:  0  batch:  100 [  1000/9000]  loss: 2.11050940  accuracy:  11.200%  Duration: 352 seconds
# epoch:  0  batch:  200 [  2000/9000]  loss: 1.88347244  accuracy:  17.950%  Duration: 702 seconds
# epoch:  0  batch:  300 [  3000/9000]  loss: 2.04785585  accuracy:  30.667%  Duration: 1052 seconds
# epoch:  0  batch:  400 [  4000/9000]  loss: 0.72469008  accuracy:  38.750%  Duration: 1400 seconds
# epoch:  0  batch:  500 [  5000/9000]  loss: 0.90821284  accuracy:  44.560%  Duration: 1747 seconds
# epoch:  0  batch:  600 [  6000/9000]  loss: 0.87239295  accuracy:  49.283%  Duration: 2094 seconds
# epoch:  0  batch:  700 [  7000/9000]  loss: 0.72887045  accuracy:  52.971%  Duration: 2445 seconds
# epoch:  0  batch:  800 [  8000/9000]  loss: 0.25825691  accuracy:  55.950%  Duration: 2790 seconds
# epoch:  0  batch:  900 [  9000/9000]  loss: 0.81504619  accuracy:  58.567%  Duration: 3137 seconds
# epoch:  1  batch:  100 [  1000/9000]  loss: 0.55949914  accuracy:  80.700%  Duration: 3702 seconds
# epoch:  1  batch:  200 [  2000/9000]  loss: 1.30230880  accuracy:  80.800%  Duration: 3715 seconds
# epoch:  1  batch:  300 [  3000/9000]  loss: 0.86795914  accuracy:  80.233%  Duration: 3729 seconds
# epoch:  1  batch:  400 [  4000/9000]  loss: 0.68760020  accuracy:  80.375%  Duration: 3742 seconds
# epoch:  1  batch:  500 [  5000/9000]  loss: 1.27556014  accuracy:  80.880%  Duration: 3756 seconds
# epoch:  1  batch:  600 [  6000/9000]  loss: 1.24826980  accuracy:  81.100%  Duration: 3769 seconds
# epoch:  1  batch:  700 [  7000/9000]  loss: 0.03569542  accuracy:  81.243%  Duration: 3783 seconds
# epoch:  1  batch:  800 [  8000/9000]  loss: 0.27963930  accuracy:  81.537%  Duration: 3796 seconds
# epoch:  1  batch:  900 [  9000/9000]  loss: 0.51350176  accuracy:  81.867%  Duration: 3810 seconds
# epoch:  2  batch:  100 [  1000/9000]  loss: 0.46588555  accuracy:  86.600%  Duration: 3835 seconds
# epoch:  2  batch:  200 [  2000/9000]  loss: 0.36521184  accuracy:  86.700%  Duration: 3849 seconds
# epoch:  2  batch:  300 [  3000/9000]  loss: 0.11874729  accuracy:  86.100%  Duration: 3863 seconds
# epoch:  2  batch:  400 [  4000/9000]  loss: 1.30345690  accuracy:  85.925%  Duration: 3876 seconds
# epoch:  2  batch:  500 [  5000/9000]  loss: 0.84830779  accuracy:  85.780%  Duration: 3890 seconds
# epoch:  2  batch:  600 [  6000/9000]  loss: 0.63775510  accuracy:  85.617%  Duration: 3903 seconds
# epoch:  2  batch:  700 [  7000/9000]  loss: 0.85048437  accuracy:  85.543%  Duration: 3917 seconds
# epoch:  2  batch:  800 [  8000/9000]  loss: 0.17350800  accuracy:  85.787%  Duration: 3930 seconds
# epoch:  2  batch:  900 [  9000/9000]  loss: 0.15992872  accuracy:  85.978%  Duration: 3944 seconds
# epoch:  3  batch:  100 [  1000/9000]  loss: 0.95327204  accuracy:  89.500%  Duration: 3970 seconds
# epoch:  3  batch:  200 [  2000/9000]  loss: 0.12706868  accuracy:  90.600%  Duration: 3983 seconds
# epoch:  3  batch:  300 [  3000/9000]  loss: 0.63633728  accuracy:  90.500%  Duration: 3996 seconds
# epoch:  3  batch:  400 [  4000/9000]  loss: 0.19404362  accuracy:  90.100%  Duration: 4010 seconds
# epoch:  3  batch:  500 [  5000/9000]  loss: 0.20522447  accuracy:  90.240%  Duration: 4023 seconds
# epoch:  3  batch:  600 [  6000/9000]  loss: 0.01939945  accuracy:  90.017%  Duration: 4037 seconds
# epoch:  3  batch:  700 [  7000/9000]  loss: 0.52672124  accuracy:  89.971%  Duration: 4050 seconds
# epoch:  3  batch:  800 [  8000/9000]  loss: 0.80409324  accuracy:  89.700%  Duration: 4063 seconds
# epoch:  3  batch:  900 [  9000/9000]  loss: 0.08793094  accuracy:  89.711%  Duration: 4077 seconds
# epoch:  4  batch:  100 [  1000/9000]  loss: 0.16458760  accuracy:  91.500%  Duration: 4103 seconds
# epoch:  4  batch:  200 [  2000/9000]  loss: 0.00218156  accuracy:  92.250%  Duration: 4116 seconds
# epoch:  4  batch:  300 [  3000/9000]  loss: 0.09540271  accuracy:  92.667%  Duration: 4130 seconds
# epoch:  4  batch:  400 [  4000/9000]  loss: 0.09943881  accuracy:  92.375%  Duration: 4143 seconds
# epoch:  4  batch:  500 [  5000/9000]  loss: 0.15902159  accuracy:  92.480%  Duration: 4157 seconds
# epoch:  4  batch:  600 [  6000/9000]  loss: 0.14338475  accuracy:  92.300%  Duration: 4171 seconds
# epoch:  4  batch:  700 [  7000/9000]  loss: 0.57675594  accuracy:  92.371%  Duration: 4184 seconds
# epoch:  4  batch:  800 [  8000/9000]  loss: 0.18042783  accuracy:  92.162%  Duration: 4197 seconds
# epoch:  4  batch:  900 [  9000/9000]  loss: 0.04015785  accuracy:  92.144%  Duration: 4211 seconds
# epoch:  5  batch:  100 [  1000/9000]  loss: 0.17127725  accuracy:  92.900%  Duration: 4237 seconds
# epoch:  5  batch:  200 [  2000/9000]  loss: 0.12001649  accuracy:  93.150%  Duration: 4250 seconds
# epoch:  5  batch:  300 [  3000/9000]  loss: 0.38309732  accuracy:  93.233%  Duration: 4264 seconds
# epoch:  5  batch:  400 [  4000/9000]  loss: 0.14176929  accuracy:  93.075%  Duration: 4277 seconds
# epoch:  5  batch:  500 [  5000/9000]  loss: 0.45646390  accuracy:  93.220%  Duration: 4291 seconds
# epoch:  5  batch:  600 [  6000/9000]  loss: 0.15405832  accuracy:  93.300%  Duration: 4304 seconds
# epoch:  5  batch:  700 [  7000/9000]  loss: 0.37643948  accuracy:  93.400%  Duration: 4317 seconds
# epoch:  5  batch:  800 [  8000/9000]  loss: 0.01185931  accuracy:  93.500%  Duration: 4331 seconds
# epoch:  5  batch:  900 [  9000/9000]  loss: 0.03845500  accuracy:  93.411%  Duration: 4344 seconds
# epoch:  6  batch:  100 [  1000/9000]  loss: 0.29540443  accuracy:  94.800%  Duration: 4370 seconds
# epoch:  6  batch:  200 [  2000/9000]  loss: 0.00580525  accuracy:  94.450%  Duration: 4383 seconds
# epoch:  6  batch:  300 [  3000/9000]  loss: 0.00482839  accuracy:  94.900%  Duration: 4397 seconds
# epoch:  6  batch:  400 [  4000/9000]  loss: 0.01415284  accuracy:  94.575%  Duration: 4410 seconds
# epoch:  6  batch:  500 [  5000/9000]  loss: 0.06441085  accuracy:  94.420%  Duration: 4424 seconds
# epoch:  6  batch:  600 [  6000/9000]  loss: 0.10281239  accuracy:  94.533%  Duration: 4437 seconds
# epoch:  6  batch:  700 [  7000/9000]  loss: 0.03005922  accuracy:  94.757%  Duration: 4451 seconds
# epoch:  6  batch:  800 [  8000/9000]  loss: 0.24368040  accuracy:  94.938%  Duration: 4464 seconds
# epoch:  6  batch:  900 [  9000/9000]  loss: 0.03621138  accuracy:  94.922%  Duration: 4478 seconds
# epoch:  7  batch:  100 [  1000/9000]  loss: 0.00484402  accuracy:  96.800%  Duration: 4504 seconds
# epoch:  7  batch:  200 [  2000/9000]  loss: 0.09689821  accuracy:  97.450%  Duration: 4517 seconds
# epoch:  7  batch:  300 [  3000/9000]  loss: 0.22551313  accuracy:  96.967%  Duration: 4531 seconds
# epoch:  7  batch:  400 [  4000/9000]  loss: 0.31702209  accuracy:  96.575%  Duration: 4544 seconds
# epoch:  7  batch:  500 [  5000/9000]  loss: 0.00563412  accuracy:  96.260%  Duration: 4558 seconds
# epoch:  7  batch:  600 [  6000/9000]  loss: 0.04710986  accuracy:  96.217%  Duration: 4571 seconds
# epoch:  7  batch:  700 [  7000/9000]  loss: 0.01599164  accuracy:  95.957%  Duration: 4585 seconds
# epoch:  7  batch:  800 [  8000/9000]  loss: 0.13155866  accuracy:  95.675%  Duration: 4598 seconds
# epoch:  7  batch:  900 [  9000/9000]  loss: 0.08603498  accuracy:  95.511%  Duration: 4612 seconds
# epoch:  8  batch:  100 [  1000/9000]  loss: 0.00383879  accuracy:  97.800%  Duration: 4638 seconds
# epoch:  8  batch:  200 [  2000/9000]  loss: 0.00866175  accuracy:  97.800%  Duration: 4651 seconds
# epoch:  8  batch:  300 [  3000/9000]  loss: 0.00826794  accuracy:  97.467%  Duration: 4665 seconds
# epoch:  8  batch:  400 [  4000/9000]  loss: 0.50523347  accuracy:  97.225%  Duration: 4678 seconds
# epoch:  8  batch:  500 [  5000/9000]  loss: 0.00133419  accuracy:  97.120%  Duration: 4692 seconds
# epoch:  8  batch:  600 [  6000/9000]  loss: 0.12713237  accuracy:  96.933%  Duration: 4705 seconds
# epoch:  8  batch:  700 [  7000/9000]  loss: 0.09919263  accuracy:  96.929%  Duration: 4719 seconds
# epoch:  8  batch:  800 [  8000/9000]  loss: 0.08194946  accuracy:  96.812%  Duration: 4732 seconds
# epoch:  8  batch:  900 [  9000/9000]  loss: 0.00111056  accuracy:  96.667%  Duration: 4746 seconds
# epoch:  9  batch:  100 [  1000/9000]  loss: 0.08631487  accuracy:  95.200%  Duration: 4772 seconds
# epoch:  9  batch:  200 [  2000/9000]  loss: 0.01771214  accuracy:  95.350%  Duration: 4785 seconds
# epoch:  9  batch:  300 [  3000/9000]  loss: 0.72659963  accuracy:  95.767%  Duration: 4799 seconds
# epoch:  9  batch:  400 [  4000/9000]  loss: 0.01113220  accuracy:  95.800%  Duration: 4813 seconds
# epoch:  9  batch:  500 [  5000/9000]  loss: 0.00519455  accuracy:  95.800%  Duration: 4826 seconds
# epoch:  9  batch:  600 [  6000/9000]  loss: 0.05884723  accuracy:  96.150%  Duration: 4839 seconds
# epoch:  9  batch:  700 [  7000/9000]  loss: 0.04187337  accuracy:  96.143%  Duration: 4853 seconds
# epoch:  9  batch:  800 [  8000/9000]  loss: 0.21700434  accuracy:  96.125%  Duration: 4866 seconds
# epoch:  9  batch:  900 [  9000/9000]  loss: 0.11580078  accuracy:  96.100%  Duration: 4880 seconds
#
# Duration: 4892 seconds

# %%
print(test_correct)
print()
print(f'Test accuracy: {test_correct[-1].item()*100/1600:.3f}%')
# Out:
# [tensor(1258), tensor(1379), tensor(1430), tensor(1440), tensor(1465), tensor(1494), tensor(1470), tensor(1508), tensor(1483), tensor(1519)]
#
# Test accuracy: 94.938%

# %%
# Create a loader for the entire the test set
test_load_all = DataLoader(test_data, batch_size=1600, shuffle=False)

with torch.no_grad():
    correct = 0
    for X_test, y_test in test_load_all:
        y_val = model(X_test)
        predicted = torch.max(y_val,1)[1]
        correct += (predicted == y_test).sum()

arr = confusion_matrix(y_test.view(-1), predicted.view(-1))
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();

# %%
plt.plot([t/90 for t in train_correct], label='training accuracy')
plt.plot([t/16 for t in test_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %%
plt.plot(train_losses, label='training loss')
plt.plot(test_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();

# %%
torch.save(model.state_dict(), 'SPLITFC2:3.pt')
